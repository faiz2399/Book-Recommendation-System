# %%
from google.colab import drive

import time
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import association_rules
from math import nan, isnan
from mlxtend.frequent_patterns import apriori

# %%
df_book_ratings = pd.read_csv('/content/gdrive/MyDrive/Ratings.csv',encoding='unicode_escape')
df_books = pd.read_csv('/content/gdrive/MyDrive/Books.csv')
df_users = pd.read_csv('/content/gdrive/MyDrive/Users.csv',encoding='unicode_escape')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_book_ratings
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
df_books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# 1       Richard Bruce Wright                2001
# 2               Carlo D'Este                1991
# 3           Gina Bari Kolata                1999
# 4            E. J. W. Barber                1999
# ...                      ...                 ...
# 271355        Paula Danziger                1988
# 271356            Teri Sloat                1991
# 271357      Christine Wicker                2004
# 271358                 Plato                1996
# 271359   Christopher  Biffle                2000
#
#                                                Publisher  \
# 0                                Oxford University Press
# 1                                  HarperFlamingo Canada
# 2                                        HarperPerennial
# 3                                   Farrar Straus Giroux
# 4                             W. W. Norton &amp; Company
# ...                                                  ...
# 271355                   Random House Childrens Pub (Mm)
# 271356                                      Dutton Books
# 271357                                HarperSanFrancisco
# 271358                           Oxford University Press
# 271359  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-L
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
# [271360 rows x 8 columns]

# %%
df_final = pd.merge(df_book_ratings,df_books,on = ['ISBN'],how='left')

# %%
df_final = pd.merge(df_final,df_users, on= ['User-ID'], how='left')

# %%
df_null  = df_final[df_final['Book-Title'].isnull()]

# %%
df_null
# Out:
#          User-ID         ISBN  Book-Rating Book-Title Book-Author  \
# 6         276736   3257224281            8        NaN         NaN
# 7         276737   0600570967            6        NaN         NaN
# 9         276745    342310538           10        NaN         NaN
# 25        276748   3442437407            0        NaN         NaN
# 26        276751   033390804X            0        NaN         NaN
# ...          ...          ...          ...        ...         ...
# 1149444   276675   0747252327            0        NaN         NaN
# 1149446   276679   8804413530            8        NaN         NaN
# 1149581   276680   0679781587            9        NaN         NaN
# 1149758   276697   8445072897            0        NaN         NaN
# 1149779   276723  05162443314            8        NaN         NaN
#
#         Year-Of-Publication Publisher Image-URL-S Image-URL-M Image-URL-L  \
# 6                       NaN       NaN         NaN         NaN         NaN
# 7                       NaN       NaN         NaN         NaN         NaN
# 9                       NaN       NaN         NaN         NaN         NaN
# 25                      NaN       NaN         NaN         NaN         NaN
# 26                      NaN       NaN         NaN         NaN         NaN
# ...                     ...       ...         ...         ...         ...
# 1149444                 NaN       NaN         NaN         NaN         NaN
# 1149446                 NaN       NaN         NaN         NaN         NaN
# 1149581                 NaN       NaN         NaN         NaN         NaN
# 1149758                 NaN       NaN         NaN         NaN         NaN
# 1149779                 NaN       NaN         NaN         NaN         NaN
#
#                                                  Location   Age
# 6                             salzburg, salzburg, austria   NaN
# 7                      sydney, new south wales, australia  14.0
# 9                                 berlin, berlin, germany  27.0
# 25       jubail ind.-city, eastern province, saudi arabia  39.0
# 26                               zuerich, zh, switzerland   NaN
# ...                                                   ...   ...
# 1149444                  mooroolbark, victoria, australia  57.0
# 1149446           beverly hills, yukon territory, vietnam   NaN
# 1149581                  hopewell junction, new york, usa  55.0
# 1149758                           oviedo, asturias, spain  29.0
# 1149779                           san antonio, texas, usa  12.0
#
# [118644 rows x 12 columns]

# %%
df_drop_null = df_final.dropna()

# %%
df_drop_null = df_drop_null.drop(['Image-URL-S','Image-URL-M','Image-URL-L'],axis=1)

# %%
df_drop_null
# Out:
#          User-ID        ISBN  Book-Rating  \
# 2         276727  0446520802            0
# 3         276729  052165615X            3
# 4         276729  0521795028            6
# 5         276733  2080674722            0
# 16        276747  0060517794            9
# ...          ...         ...          ...
# 1149756   276690  0590581066            0
# 1149757   276690  0590907301            0
# 1149776   276706  0679447156            0
# 1149777   276709  0515107662           10
# 1149778   276721  0590442449           10
#
#                                                 Book-Title  \
# 2                                             The Notebook
# 3                                           Help!: Level 1
# 4        The Amsterdam Connection : Level 4 (Cambridge ...
# 5                              Les Particules Elementaires
# 16                                Little Altars Everywhere
# ...                                                    ...
# 1149756  Triplet Trouble and the Red Heart Race (Triple...
# 1149757  Triplet Trouble and the Class Trip (Triplet Tr...
# 1149776  Eight Weeks to Optimum Health: A Proven Progra...
# 1149777   The Sherbrooke Bride (Bride Trilogy (Paperback))
# 1149778                                  Fourth Grade Rats
#
#                 Book-Author Year-Of-Publication                   Publisher  \
# 2           Nicholas Sparks                1996                Warner Books
# 3             Philip Prowse                1999  Cambridge University Press
# 4               Sue Leather                2001  Cambridge University Press
# 5        Michel Houellebecq                1998                  Flammarion
# 16            Rebecca Wells                2003                 HarperTorch
# ...                     ...                 ...                         ...
# 1149756        Debbie Dadey                1996       Scholastic Paperbacks
# 1149757        Debbie Dadey                1997                       Apple
# 1149776         Andrew Weil                1997             Alfred A. Knopf
# 1149777   Catherine Coulter                1996                  Jove Books
# 1149778      Jerry Spinelli                1996                  Scholastic
#
#                                Location   Age
# 2         h, new south wales, australia  16.0
# 3                  rijeka, n/a, croatia  16.0
# 4                  rijeka, n/a, croatia  16.0
# 5                    paris, n/a, france  37.0
# 16                 iowa city, iowa, usa  25.0
# ...                                 ...   ...
# 1149756              wakeman, ohio, usa  43.0
# 1149757              wakeman, ohio, usa  43.0
# 1149776          quebec, quebec, canada  18.0
# 1149777  mannington, west virginia, usa  38.0
# 1149778   providence, rhode island, usa  14.0
#
# [753296 rows x 9 columns]

# %%
most_read = df_drop_null['Book-Title'].value_counts().reset_index()
most_read.columns = ['Book-Title', 'COUNT']

# %%
most_read.shape
# Out:
# (205170, 2)

# %%
atleast_50_books = most_read[most_read['COUNT'] >= 50]

# %%
df_final = pd.merge(atleast_50_books,df_drop_null, on= ['Book-Title'], how='left')

# %%
df_final = df_final.dropna()

# %%
df_final
# Out:
#                 Book-Title  COUNT  User-ID        ISBN  Book-Rating  \
# 0              Wild Animus   2141   276925  0971880107            0
# 1              Wild Animus   2141   276939  0971880107            0
# 2              Wild Animus   2141   276954  0971880107            0
# 3              Wild Animus   2141   277157  0971880107            0
# 4              Wild Animus   2141   277378  0971880107            0
# ...                    ...    ...      ...         ...          ...
# 169254  Sister of My Heart     50   270713  038548951X            0
# 169255  Sister of My Heart     50   273086  038548951X            0
# 169256  Sister of My Heart     50   273587  038548951X            0
# 169257  Sister of My Heart     50   274004  038548951X            8
# 169258  Sister of My Heart     50   275111  038548951X            8
#
#                        Book-Author Year-Of-Publication   Publisher  \
# 0                     Rich Shapero                2004     Too Far
# 1                     Rich Shapero                2004     Too Far
# 2                     Rich Shapero                2004     Too Far
# 3                     Rich Shapero                2004     Too Far
# 4                     Rich Shapero                2004     Too Far
# ...                            ...                 ...         ...
# 169254  Chitra Banerjee Divakaruni                2000  Anchor Pub
# 169255  Chitra Banerjee Divakaruni                2000  Anchor Pub
# 169256  Chitra Banerjee Divakaruni                2000  Anchor Pub
# 169257  Chitra Banerjee Divakaruni                2000  Anchor Pub
# 169258  Chitra Banerjee Divakaruni                2000  Anchor Pub
#
#                                          Location   Age
# 0                     barcelona, barcelona, spain  22.0
# 1                        poissy, yvelines, france  23.0
# 2           freiburg, baden-wuerttemberg, germany  43.0
# 3                   garden grove, california, usa  70.0
# 4             vancouver, british columbia, canada  33.0
# ...                                           ...   ...
# 169254                   toronto, ontario, canada  27.0
# 169255                     chicago, illinois, usa  33.0
# 169256        den haag, zuid-holland, netherlands  60.0
# 169257  sydenham, london, england, united kingdom  41.0
# 169258              utrecht, utrecht, netherlands  34.0
#
# [169259 rows x 10 columns]

# %%
atleast_50_books
# Out:
#                                              Book-Title  COUNT
# 0                                           Wild Animus   2141
# 1                             The Lovely Bones: A Novel    920
# 2                                     The Da Vinci Code    708
# 3                                 Bridget Jones's Diary    599
# 4                            The Nanny Diaries: A Novel    573
# ...                                                 ...    ...
# 1568                                      Hornet Flight     50
# 1569                                            Passage     50
# 1570                                        Last Orders     50
# 1571  Confessions of a Sociopathic Social Climber : ...     50
# 1572                                 Sister of My Heart     50
#
# [1573 rows x 2 columns]

# %%
most_user = df_drop_null['User-ID'].value_counts().reset_index()
most_user.columns = ['User-ID', 'COUNT']

# %%
atleast_200_users = most_user[most_user['COUNT'] >= 200]

# %%
df_final = pd.merge(atleast_200_users,df_final, on= ['User-ID'], how='left')

# %%
df_final = df_final.dropna()

# %%
df_final
# Out:
#        User-ID  COUNT_x                                         Book-Title  \
# 0       198711     6456                                        Wild Animus
# 1       198711     6456                                    A Painted House
# 2       198711     6456    Divine Secrets of the Ya-Ya Sisterhood: A Novel
# 3       198711     6456                                       The Notebook
# 4       198711     6456   Harry Potter and the Chamber of Secrets (Book 2)
# ...        ...      ...                                                ...
# 69948   141902      200                                   SEAT OF THE SOUL
# 69949   141902      200  Apollyon: The Destroyer Is Unleashed (Left Beh...
# 69950   141902      200                 Gap Creek: The Story of a Marriage
# 69951   141902      200                                     True Betrayals
# 69952   141902      200                                       The Presence
#
#        COUNT_y        ISBN  Book-Rating      Book-Author Year-Of-Publication  \
# 0         2141  0971880107            0     Rich Shapero                2004
# 1          517  044023722X            0     John Grisham                2001
# 2          514  0060928336            0    Rebecca Wells                1997
# 3          456  0446605239            0  Nicholas Sparks                1998
# 4          425  0439064872            0    J. K. Rowling                2000
# ...        ...         ...          ...              ...                 ...
# 69948       61  067169507X           10       Gary Zukav                1990
# 69949       59  0842329269            0    Jerry Jenkins                2000
# 69950       58  074322535X           10    Robert Morgan                2001
# 69951       53  0515118559            0     Nora Roberts                1996
# 69952       51  0449002411            7        John Saul                1998
#
#                       Publisher                       Location   Age
# 0                       Too Far  little canada, minnesota, usa  62.0
# 1       Dell Publishing Company  little canada, minnesota, usa  62.0
# 2                     Perennial  little canada, minnesota, usa  62.0
# 3                  Warner Books  little canada, minnesota, usa  62.0
# 4                    Scholastic  little canada, minnesota, usa  62.0
# ...                         ...                            ...   ...
# 69948                Free Press    newport news, virginia, usa  51.0
# 69949  Tyndale House Publishers    newport news, virginia, usa  51.0
# 69950                Touchstone    newport news, virginia, usa  51.0
# 69951                Jove Books    newport news, virginia, usa  51.0
# 69952          Ballantine Books    newport news, virginia, usa  51.0
#
# [69953 rows x 11 columns]

# %%
df_final = df_final.rename(columns = {'COUNT_x':'Books_User_Rated','COUNT_y':'Book_Was_Rated'})

# %%
df_final
# Out:
#        User-ID  Books_User_Rated  \
# 0       198711              6456
# 1       198711              6456
# 2       198711              6456
# 3       198711              6456
# 4       198711              6456
# ...        ...               ...
# 69948   141902               200
# 69949   141902               200
# 69950   141902               200
# 69951   141902               200
# 69952   141902               200
#
#                                               Book-Title  Book_Was_Rated  \
# 0                                            Wild Animus            2141
# 1                                        A Painted House             517
# 2        Divine Secrets of the Ya-Ya Sisterhood: A Novel             514
# 3                                           The Notebook             456
# 4       Harry Potter and the Chamber of Secrets (Book 2)             425
# ...                                                  ...             ...
# 69948                                   SEAT OF THE SOUL              61
# 69949  Apollyon: The Destroyer Is Unleashed (Left Beh...              59
# 69950                 Gap Creek: The Story of a Marriage              58
# 69951                                     True Betrayals              53
# 69952                                       The Presence              51
#
#              ISBN  Book-Rating      Book-Author Year-Of-Publication  \
# 0      0971880107            0     Rich Shapero                2004
# 1      044023722X            0     John Grisham                2001
# 2      0060928336            0    Rebecca Wells                1997
# 3      0446605239            0  Nicholas Sparks                1998
# 4      0439064872            0    J. K. Rowling                2000
# ...           ...          ...              ...                 ...
# 69948  067169507X           10       Gary Zukav                1990
# 69949  0842329269            0    Jerry Jenkins                2000
# 69950  074322535X           10    Robert Morgan                2001
# 69951  0515118559            0     Nora Roberts                1996
# 69952  0449002411            7        John Saul                1998
#
#                       Publisher                       Location   Age
# 0                       Too Far  little canada, minnesota, usa  62.0
# 1       Dell Publishing Company  little canada, minnesota, usa  62.0
# 2                     Perennial  little canada, minnesota, usa  62.0
# 3                  Warner Books  little canada, minnesota, usa  62.0
# 4                    Scholastic  little canada, minnesota, usa  62.0
# ...                         ...                            ...   ...
# 69948                Free Press    newport news, virginia, usa  51.0
# 69949  Tyndale House Publishers    newport news, virginia, usa  51.0
# 69950                Touchstone    newport news, virginia, usa  51.0
# 69951                Jove Books    newport news, virginia, usa  51.0
# 69952          Ballantine Books    newport news, virginia, usa  51.0
#
# [69953 rows x 11 columns]

# %%
import seaborn as sns

# %%
sns.boxplot(data = df_final, x='Age')

# %%
df_final = df_final[df_final['Age']<100]

# %%
df_final = df_final[df_final['Age']>4]

# %%
df_final['Age'].max()
# Out:
# 69.0

# %%
df_final
# Out:
#        User-ID  Books_User_Rated  \
# 0       198711              6456
# 1       198711              6456
# 2       198711              6456
# 3       198711              6456
# 4       198711              6456
# ...        ...               ...
# 69948   141902               200
# 69949   141902               200
# 69950   141902               200
# 69951   141902               200
# 69952   141902               200
#
#                                               Book-Title  Book_Was_Rated  \
# 0                                            Wild Animus            2141
# 1                                        A Painted House             517
# 2        Divine Secrets of the Ya-Ya Sisterhood: A Novel             514
# 3                                           The Notebook             456
# 4       Harry Potter and the Chamber of Secrets (Book 2)             425
# ...                                                  ...             ...
# 69948                                   SEAT OF THE SOUL              61
# 69949  Apollyon: The Destroyer Is Unleashed (Left Beh...              59
# 69950                 Gap Creek: The Story of a Marriage              58
# 69951                                     True Betrayals              53
# 69952                                       The Presence              51
#
#              ISBN  Book-Rating      Book-Author Year-Of-Publication  \
# 0      0971880107            0     Rich Shapero                2004
# 1      044023722X            0     John Grisham                2001
# 2      0060928336            0    Rebecca Wells                1997
# 3      0446605239            0  Nicholas Sparks                1998
# 4      0439064872            0    J. K. Rowling                2000
# ...           ...          ...              ...                 ...
# 69948  067169507X           10       Gary Zukav                1990
# 69949  0842329269            0    Jerry Jenkins                2000
# 69950  074322535X           10    Robert Morgan                2001
# 69951  0515118559            0     Nora Roberts                1996
# 69952  0449002411            7        John Saul                1998
#
#                       Publisher                       Location   Age
# 0                       Too Far  little canada, minnesota, usa  62.0
# 1       Dell Publishing Company  little canada, minnesota, usa  62.0
# 2                     Perennial  little canada, minnesota, usa  62.0
# 3                  Warner Books  little canada, minnesota, usa  62.0
# 4                    Scholastic  little canada, minnesota, usa  62.0
# ...                         ...                            ...   ...
# 69948                Free Press    newport news, virginia, usa  51.0
# 69949  Tyndale House Publishers    newport news, virginia, usa  51.0
# 69950                Touchstone    newport news, virginia, usa  51.0
# 69951                Jove Books    newport news, virginia, usa  51.0
# 69952          Ballantine Books    newport news, virginia, usa  51.0
#
# [69531 rows x 11 columns]

# %%
df_final['Age'].describe()
# Out:
# count    69531.000000
# mean        37.392300
# std         10.917806
# min          9.000000
# 25%         29.000000
# 50%         36.000000
# 75%         45.000000
# max         69.000000
# Name: Age, dtype: float64

# %%
df_final['Age'].hist()

# %%
df_final_list = df_final.groupby('User-ID')['Book-Title'].apply(list).reset_index()

# %%
df_final_list
# Out:
#      User-ID                                         Book-Title
# 0        254  [Bridget Jones's Diary, The Secret Life of Bee...
# 1       2276  [The Runaway Jury, The Brethren, The King of T...
# 2       2766  [Wild Animus, The Lovely Bones: A Novel, The S...
# 3       2977  [Wild Animus, The Testament, The Firm, Jurassi...
# 4       3363  [Wild Animus, The Lovely Bones: A Novel, The D...
# ..       ...                                                ...
# 636   274301  [Wild Animus, The Nanny Diaries: A Novel, The ...
# 637   274308  [The Da Vinci Code, Bridget Jones's Diary, Ang...
# 638   275970  [The Secret Life of Bees, Divine Secrets of th...
# 639   277427  [Wild Animus, The Lovely Bones: A Novel, The D...
# 640   277639  [The Pelican Brief, A Time to Kill, The Horse ...
#
# [641 rows x 2 columns]

# %%
df_lst = df_final_list['Book-Title'].to_list()

# %%
te = TransactionEncoder()

# %%
te_arr = te.fit(df_lst).transform(df_lst)

# %%
df_ap = pd.DataFrame(te_arr, columns=te.columns_)

# %%
df_ap
# Out:
#      16 Lighthouse Road   1984  1st to Die: A Novel  2010: Odyssey Two  \
# 0                 False   True                False              False
# 1                 False  False                False               True
# 2                 False  False                False              False
# 3                 False  False                False              False
# 4                 False  False                False              False
# ..                  ...    ...                  ...                ...
# 636               False  False                False              False
# 637               False  False                False              False
# 638               False   True                False              False
# 639               False  False                False              False
# 640               False  False                False              False
#
#      204 Rosewood Lane  24 Hours  2nd Chance  3rd Degree  4 Blondes  \
# 0                False     False       False       False      False
# 1                False     False        True       False      False
# 2                False     False       False       False      False
# 3                False     False       False       False      False
# 4                False     False       False       False      False
# ..                 ...       ...         ...         ...        ...
# 636              False     False       False       False      False
# 637              False     False        True        True      False
# 638              False     False       False       False      False
# 639              False      True       False       False      False
# 640              False     False        True       False      False
#
#      84 Charing Cross Road  ...  \
# 0                    False  ...
# 1                    False  ...
# 2                    False  ...
# 3                    False  ...
# 4                    False  ...
# ..                     ...  ...
# 636                  False  ...
# 637                  False  ...
# 638                   True  ...
# 639                  False  ...
# 640                  False  ...
#
#      Word Freak: Heartbreak, Triumph, Genius, and Obsession in the World of Competitive Scrabble Players  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 636                                              False
# 637                                              False
# 638                                              False
# 639                                              False
# 640                                              False
#
#      Wouldn't Take Nothing for My Journey Now  Writ of Execution  \
# 0                                       False              False
# 1                                       False              False
# 2                                       False              False
# 3                                       False              False
# 4                                       False              False
# ..                                        ...                ...
# 636                                     False              False
# 637                                     False               True
# 638                                     False              False
# 639                                     False              False
# 640                                     False              False
#
#      Wuthering Heights  Wuthering Heights (Penguin Classics)  Year of Wonders  \
# 0                False                                 False            False
# 1                False                                 False            False
# 2                False                                 False            False
# 3                False                                 False             True
# 4                False                                 False            False
# ..                 ...                                   ...              ...
# 636              False                                 False            False
# 637               True                                 False            False
# 638              False                                 False             True
# 639              False                                 False            False
# 640              False                                 False            False
#
#      You Belong To Me  \
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# ..                ...
# 636             False
# 637             False
# 638             False
# 639             False
# 640             False
#
#      Zen and the Art of Motorcycle Maintenance: An Inquiry into Values   Zoya  \
# 0                                                False                  False
# 1                                                False                  False
# 2                                                False                  False
# 3                                                False                  False
# 4                                                 True                  False
# ..                                                 ...                    ...
# 636                                              False                  False
# 637                                              False                  False
# 638                                               True                  False
# 639                                              False                  False
# 640                                              False                  False
#
#      \O\" Is for Outlaw"
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
# ..                   ...
# 636                 True
# 637                False
# 638                False
# 639                False
# 640                False
#
# [641 rows x 1572 columns]

# %%
frequent_sets = apriori(df_ap,min_support = 0.1, use_colnames=True)

# %%
frequent_sets
# Out:
#       support                                           itemsets
# 0    0.179407                              (1st to Die: A Novel)
# 1    0.137285                                       (2nd Chance)
# 2    0.126365                               (A Bend in the Road)
# 3    0.101404  (A Child Called \It\": One Child's Courage to ...
# 4    0.162246  (A Is for Alibi (Kinsey Millhone Mysteries (Pa...
# ..        ...                                                ...
# 317  0.104524               (Wild Animus, To Kill a Mockingbird)
# 318  0.101404  (Wild Animus, Tuesdays with Morrie: An Old Man...
# 319  0.109204  (Wild Animus, Where the Heart Is (Oprah's Book...
# 320  0.101404    (A Time to Kill, The Pelican Brief, The Client)
# 321  0.101404      (The Firm, A Time to Kill, The Pelican Brief)
#
# [322 rows x 2 columns]

# %%
confidence_1 = association_rules(frequent_sets, metric="confidence",
                  min_threshold=0.4).sort_values('lift', ascending=False)

# %%
confidence_1.to_excel("rules.xlsx")

# %%
confidence_1.to_csv('data.xlsx')
# !cp data.xlsx "/content/gdrive/MyDrive"

# %%
df_final['ISBN'] = df_final['ISBN'].apply(lambda x: x.zfill(10))

# %%
lst_book = df_final['ISBN'].to_list()

# %%
lst_book = list(set(lst_book))

# %%
import json
from urllib.request import urlopen
import time

# %%
# from tqdm import tqdm
# chunk_size = 300
# lst_book1 = [lst_book[i:i + chunk_size] for i in range(0, len(lst_book), chunk_size)]

# %%
# isbn_book = []
# genre_book = []
# api = "https://www.googleapis.com/books/v1/volumes?q=isbn:"
# for book in tqdm(lst_book1[12]):
#   isbn = book.strip()

#   resp = urlopen(api + isbn)
#   book_data = json.load(resp)
#   if 'items' in book_data and 'volumeInfo' in book_data['items'][0]:
#         isbn_book.append(book_data['items'][0]['volumeInfo']['industryIdentifiers'][0]['identifier'])
#         if 'categories' in book_data['items'][0]['volumeInfo']:
#             genre_book.append(book_data['items'][0]['volumeInfo']['categories'][0])
#         else:
#             genre_book.append("no category")
#   else:
#     isbn_book.append("no book")
#     genre_book.append("no category")
#   time.sleep(5)

# df_genre = pd.DataFrame({'ISBN':isbn_book,'Genre':genre_book})
# Out:
# 100%|██████████| 300/300 [26:36<00:00,  5.32s/it]

# %%
df_genre = pd.DataFrame()

for i in range(14):

  df = pd.read_csv(f'/content/gdrive/MyDrive/book_genre/chunk{i+1}.csv')
  df = df.drop('Unnamed: 0',axis=1)
  df_genre = pd.concat([df_genre,df])

# %%
df_genre = df_genre[df_genre['ISBN'] != 'no book']

# %%
df_final
# Out:
#        User-ID  Books_User_Rated  \
# 0       198711              6456
# 1       198711              6456
# 2       198711              6456
# 3       198711              6456
# 4       198711              6456
# ...        ...               ...
# 69948   141902               200
# 69949   141902               200
# 69950   141902               200
# 69951   141902               200
# 69952   141902               200
#
#                                               Book-Title  Book_Was_Rated  \
# 0                                            Wild Animus            2141
# 1                                        A Painted House             517
# 2        Divine Secrets of the Ya-Ya Sisterhood: A Novel             514
# 3                                           The Notebook             456
# 4       Harry Potter and the Chamber of Secrets (Book 2)             425
# ...                                                  ...             ...
# 69948                                   SEAT OF THE SOUL              61
# 69949  Apollyon: The Destroyer Is Unleashed (Left Beh...              59
# 69950                 Gap Creek: The Story of a Marriage              58
# 69951                                     True Betrayals              53
# 69952                                       The Presence              51
#
#              ISBN  Book-Rating      Book-Author Year-Of-Publication  \
# 0      0971880107            0     Rich Shapero                2004
# 1      044023722X            0     John Grisham                2001
# 2      0060928336            0    Rebecca Wells                1997
# 3      0446605239            0  Nicholas Sparks                1998
# 4      0439064872            0    J. K. Rowling                2000
# ...           ...          ...              ...                 ...
# 69948  067169507X           10       Gary Zukav                1990
# 69949  0842329269            0    Jerry Jenkins                2000
# 69950  074322535X           10    Robert Morgan                2001
# 69951  0515118559            0     Nora Roberts                1996
# 69952  0449002411            7        John Saul                1998
#
#                       Publisher                       Location   Age
# 0                       Too Far  little canada, minnesota, usa  62.0
# 1       Dell Publishing Company  little canada, minnesota, usa  62.0
# 2                     Perennial  little canada, minnesota, usa  62.0
# 3                  Warner Books  little canada, minnesota, usa  62.0
# 4                    Scholastic  little canada, minnesota, usa  62.0
# ...                         ...                            ...   ...
# 69948                Free Press    newport news, virginia, usa  51.0
# 69949  Tyndale House Publishers    newport news, virginia, usa  51.0
# 69950                Touchstone    newport news, virginia, usa  51.0
# 69951                Jove Books    newport news, virginia, usa  51.0
# 69952          Ballantine Books    newport news, virginia, usa  51.0
#
# [69531 rows x 11 columns]

# %%
df_genre_new = df_genre.drop_duplicates()

# %%
df_genre_new[['ISBN']].value_counts().to_frame().reset_index()
# Out:
#                   ISBN  0
# 0           0373484410  2
# 1        9780553210095  2
# 2        9780679457527  2
# 3           0805063897  2
# 4           0007110928  1
# ...                ... ..
# 2459        0446611212  1
# 2460        0446611476  1
# 2461        044661162X  1
# 2462        0446611638  1
# 2463  WISC:89037835972  1
#
# [2464 rows x 2 columns]

# %%
df_genre_new.to_excel("genre_isbn.xlsx")

# %%
df_genre_new[df_genre_new['ISBN'] == '0805063897']
# Out:
#            ISBN                 Genre
# 296  0805063897  Business & Economics
# 245  0805063897        Social Science

# %%
df_clean_genre = pd.read_excel('/content/gdrive/MyDrive/book_genre/genre.xlsx')

# %%
df_clean_genre
# Out:
#       Unnamed: 0           ISBN             Genre
# 0              0     0451167856           Fiction
# 1              1     0399148817           Fiction
# 2              2     0671727583           Fiction
# 3              3  9780385335836           Fiction
# 4              5     051512608X           Fiction
# ...          ...            ...               ...
# 2388          72     0802134475           Fiction
# 2389          73  9780679457527            Travel
# 2390          74     0812558626           Fiction
# 2391          75  9780553213164  Juvenile Fiction
# 2392          76     0380002930           Fiction
#
# [2393 rows x 3 columns]

# %%
df_clean_genre['Genre'] = df_clean_genre['Genre'].apply(lambda x : x.lower())

# %%
df_clean_genre['Genre'].value_counts()
# Out:
# fiction                        1763
# juvenile fiction                119
# biography & autobiography        53
# humor                            19
# horror tales                     12
#                                ...
# time travel                       1
# language arts & disciplines       1
# geishas                           1
# totalitarianism                   1
# bereavement                       1
# Name: Genre, Length: 236, dtype: int64

# %%
df_clean_genre = df_clean_genre.drop('Unnamed: 0',axis=1)

# %%
df_clean_genre['Genre']
# Out:
# 0                fiction
# 1                fiction
# 2                fiction
# 3                fiction
# 4                fiction
#               ...
# 2388             fiction
# 2389              travel
# 2390             fiction
# 2391    juvenile fiction
# 2392             fiction
# Name: Genre, Length: 2393, dtype: object

# %%
df_final_c = pd.merge(df_final,df_clean_genre, on= ['ISBN'], how='left')

# %%
df_final_c = df_final_c.dropna()

# %%
df_final_c['Genre'].value_counts()
# Out:
# fiction                      23620
# juvenile fiction              1016
# biography & autobiography      615
# humor                          347
# social science                 164
#                              ...
# christianity                     1
# college teachers                 1
# utah                             1
# african american authors         1
# rape victims                     1
# Name: Genre, Length: 212, dtype: int64

# %%
df_final_c.to_excel("/content/gdrive/MyDrive/book_genre/final_book.xlsx")
